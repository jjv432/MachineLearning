# %%
import dill

with open('trained_agent.pkl', 'rb') as f:
    trained_agent = dill.load(f)

print(trained_agent.actor_model.get_weights())

with open('trained_pendulum.pkl', 'rb') as f:
    trained_pendulum = dill.load(f)
# Out:
# [array([[-0.00275668, -0.05062728,  0.06140652,  0.1797624 ,  0.06727532,
#         -0.24941483,  0.09232309, -0.00295592, -0.06389821, -0.11604533,
#          0.15890855,  0.22839904,  0.17694552, -0.21485624,  0.02893867,
#         -0.03298196,  0.2851607 ,  0.24502179,  0.02978906, -0.2563859 ,
#         -0.13764454, -0.24142534,  0.2580503 , -0.07345965, -0.09933075,
#         -0.06247237,  0.16219914,  0.21309787, -0.19521575, -0.0634269 ,
#          0.15981297,  0.03369574, -0.02911858,  0.2239453 , -0.02259991,
#         -0.16178043, -0.10445756, -0.26196626,  0.13504326,  0.0476036 ,
#         -0.14152853,  0.00654003,  0.15780212,  0.18535675, -0.05007302,
#          0.26649147,  0.02166898,  0.23374093, -0.07031786, -0.25558826,
#          0.21749747,  0.15953057, -0.26813668, -0.14970542, -0.22761928,
#          0.2768407 , -0.06503486, -0.20353347, -0.16710195, -0.05806348,
#         -0.13467279,  0.16238709,  0.22085866,  0.25385714],
# ...
